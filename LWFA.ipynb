# %%
import visxd

import matplotlib.colors as colors

visxd.plot_data("EMF/Ex",1572, cmap = "RdBu", norm = colors.CenteredNorm())
visxd.plot_data("EMF/Ey",1572, cmap = "BrBG", norm = colors.CenteredNorm())
visxd.plot_data("EMF/Ez",1572, cmap = "PiYG", norm = colors.CenteredNorm())

visxd.plot_data("PHASESPACE/electrons/electrons-xux", 1572, norm = colors.LogNorm( vmin = 0.001) )
# Out:
# Plotting EMF/Ex-001572.zdf
# Plotting EMF/Ey-001572.zdf
# Plotting EMF/Ez-001572.zdf
# Plotting PHASESPACE/electrons/electrons-xux-001572.zdf
