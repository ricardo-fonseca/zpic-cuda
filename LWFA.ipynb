# %% [markdown]
# # Simulation of a Laser Wakefield Accelerator

# %%
import visxd

import matplotlib.colors as colors

visxd.plot_data("EMF/Ex",3143, cmap = "RdBu", norm = colors.CenteredNorm())
visxd.plot_data("EMF/Ey",3143, cmap = "BrBG", norm = colors.CenteredNorm())
visxd.plot_data("EMF/Ez",3143, cmap = "PiYG", norm = colors.CenteredNorm())

visxd.plot_data("PHASESPACE/electrons/electrons-xux", 3143, norm = colors.LogNorm( vmin = 0.001) )
# Out:
# Plotting EMF/Ex-003143.zdf
# Plotting EMF/Ey-003143.zdf
# Plotting EMF/Ez-003143.zdf
# Plotting PHASESPACE/electrons/electrons-xux-003143.zdf
