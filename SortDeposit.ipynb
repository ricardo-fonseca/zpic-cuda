# %% [markdown]
# # Test Sort-Deposit

# %%
import visxd

# %%
visxd.plot_data( "CURRENT/Jx", 1 )
visxd.plot_data( "CURRENT/Jy", 1 )
visxd.plot_data( "CURRENT/Jz", 1 )
visxd.plot_data( "CHARGE/electrons/electrons-charge", 1)
# Out:
# Plotting CURRENT/Jx-000001.zdf
# Plotting CURRENT/Jy-000001.zdf
# Plotting CURRENT/Jz-000001.zdf
# Plotting CHARGE/electrons/electrons-charge-000001.zdf
